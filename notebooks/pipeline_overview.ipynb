# %%
import pandas as pd

# %%
# %cd ..
# Out:
# /Users/adornes/Dropbox/Profissional/Consulting/TheAIAcademy/repos/adornes-cml

# %%
# %%bash
# dvc dag
# Out:
#               +---------------+
#               | load_raw_data |
#               +---------------+
#                        *
#                        *
#                        *
#                +--------------+
#                | prepare_data |
#                +--------------+
#                        *
#                        *
#                        *
#                +-------------+
#                | enrich_data |
#                +-------------+
#               ***            ***
#             **                  ***
#           **                       **
# +-------------+                      **
# | train_model |                    **
# +-------------+                 ***
#               ***            ***
#                  **        **
#                    **    **
#               +----------------+
#               | evaluate_model |
#               +----------------+

# %%
# %%bash
# dvc repro
# Out:
# Stage 'load_raw_data' didn't change, skipping
# Stage 'prepare_data' didn't change, skipping
# Stage 'enrich_data' didn't change, skipping
# Stage 'train_model' didn't change, skipping
# Stage 'evaluate_model' is cached - skipping run, checking out outputs

# %%
pd.read_csv("assets/raw_data/Sales_Transactions_Dataset_Weekly.csv").head()
# Out:
#   Product_Code  W0  W1  W2  W3  W4  W5  W6  W7  W8  ...  Normalized 42  \
# 0           P1  11  12  10   8  13  12  14  21   6  ...           0.06
# 1           P2   7   6   3   2   7   1   6   3   3  ...           0.20
# 2           P3   7  11   8   9  10   8   7  13  12  ...           0.27
# 3           P4  12   8  13   5   9   6   9  13  13  ...           0.41
# 4           P5   8   5  13  11   6   7   9  14   9  ...           0.27
#
#    Normalized 43  Normalized 44  Normalized 45  Normalized 46  Normalized 47  \
# 0           0.22           0.28           0.39           0.50           0.00
# 1           0.40           0.50           0.10           0.10           0.40
# 2           1.00           0.18           0.18           0.36           0.45
# 3           0.47           0.06           0.12           0.24           0.35
# 4           0.53           0.27           0.60           0.20           0.20
#
#    Normalized 48  Normalized 49  Normalized 50  Normalized 51
# ...

# %%
pd.read_csv("assets/prepared_data/prepared_data.csv").head()
# Out:
#    Product_Code  Week  Sales
# 0             1     0     11
# 1             2     0      7
# 2             3     0      7
# 3             4     0     12
# 4             5     0      8

# %%
pd.read_csv("assets/enriched_data/enriched_data.csv").head()
# Out:
#    Product_Code  Week  Sales  Last_Week_Sales  Last_Week_Diff
# 0             1     2     10             12.0             1.0
# 1             2     2      3              6.0            -1.0
# 2             3     2      8             11.0             4.0
# 3             4     2     13              8.0            -4.0
# 4             5     2     13              5.0            -3.0

# %%
# %%bash
# cat assets/metrics.json
# Out:
# {"r_squared": 0.8749837678187495, "rmse": 3.90975977620683, "rmsle": 0.4672756781160658}

# %%
# %%bash
# dvc metrics show -T
# Out:
# workspace:
# 	assets/metrics.json:
# 		r_squared: 0.8749837678187495
# 		rmse: 3.90975977620683
# 		rmsle: 0.4672756781160658
# dvc-ready:
# 	assets/metrics.json:
# 		r_squared: 0.8744084792695068
# 		rmse: 3.918745242889401
# 		rmsle: 0.4682367993512513
# rf-estimators-1000:
# 	assets/metrics.json:
# 		r_squared: 0.8749837678187495
# 		rmse: 3.90975977620683
# 		rmsle: 0.4672756781160658
